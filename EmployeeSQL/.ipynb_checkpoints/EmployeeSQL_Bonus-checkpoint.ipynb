# %%
# import dependecies
from sqlalchemy import create_engine
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# import keys
from config import config
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-d178754d72e0> in <module>
#       6
#       7 # import keys
# ----> 8 from config import config
#
# ImportError: cannot import name 'config' from 'config' (/Users/drewhenning/Desktop/USC/Homework/09-SQL-SQL_Homework/sql-challenge/EmployeeSQL/config.py)

# %%
# create an engine that can talk to the database
engine = create_engine('postgresql://{username}:{password}@localhost:5432/Pewlett_Hackard_employees_db')
connection = engine.connect()

# %%
# create dataframe for employees, titles and salaries
df_employees =pd.read_sql("select * from employees", connection)
df_titles = pd.read_sql("select * from titles", connection)
df_salaries = pd.read_sql("select * from salaries", connection)

# %%
# set index of df_salaries in order to create histogram
df_salaries2 = df_salaries.set_index('emp_no')
df_salaries2
# Out:
#         salary
# emp_no
# 10001    60117
# 10002    65828
# 10003    40006
# 10004    40054
# 10005    78228
# ...        ...
# 499995   40000
# 499996   58058
# 499997   49597
# 499998   40000
# 499999   63707
#
# [300024 rows x 1 columns]

# %%
# create a histogram to visualize the most common salary ranges for employees

# determine fig and ax
fig, ax = plt.subplots()

# determine type of plot and format
df_salaries2.plot(kind='hist',
                 figsize=(7,7),
                 ax=ax,
                 color="limegreen",
                 edgecolor="black",
                 title="Salary Distribution");

# rotate xticks
plt.xticks(rotation = 75)

# apply grid
ax.yaxis.grid()

# display histogram
fig.tight_layout();

# save figure
plt.savefig("../sql-challenge/Images/Bonus - Histogram Salary Distribution.png")

# %%
# merge dataframes in order to create bar chart of average salary
# merge employees and titles dataframe
df_merge = pd.merge(df_employees, df_titles, left_on='emp_title_id', right_on='title_id', how='left')
df_merge
# Out:
#         emp_no emp_title_id  birth_date   first_name  last_name sex  \
# 0       473302        s0001  1953-07-25     Hideyuki   Zallocco   M
# 1       475053        e0002  1954-11-18        Byong  Delgrande   F
# 2        57444        e0002  1958-01-30        Berry       Babb   F
# 3       421786        s0001  1957-09-28        Xiong   Verhoeff   M
# 4       282238        e0003  1952-10-28   Abdelkader    Baumann   F
# ...        ...          ...         ...          ...        ...  ..
# 300019  464231        s0001  1958-08-14  Constantino    Eastman   M
# 300020  255832        e0002  1955-05-08       Yuping     Dayang   F
# 300021   76671        s0001  1959-06-09       Ortrud   Plessier   M
# 300022  264920        s0001  1959-09-22        Percy   Samarati   F
# 300023  464503        s0002  1964-05-31       Arvind  Slobodova   M
#
#          hire_date title_id            title
# 0       1990-04-28    s0001            Staff
# 1       1991-09-07    e0002         Engineer
# ...

# %%
# merge with salaries
df_merge = pd.merge(df_merge, df_salaries, on='emp_no', how='left')
df_merge
# Out:
#         emp_no emp_title_id  birth_date   first_name  last_name sex  \
# 0       473302        s0001  1953-07-25     Hideyuki   Zallocco   M
# 1       475053        e0002  1954-11-18        Byong  Delgrande   F
# 2        57444        e0002  1958-01-30        Berry       Babb   F
# 3       421786        s0001  1957-09-28        Xiong   Verhoeff   M
# 4       282238        e0003  1952-10-28   Abdelkader    Baumann   F
# ...        ...          ...         ...          ...        ...  ..
# 300019  464231        s0001  1958-08-14  Constantino    Eastman   M
# 300020  255832        e0002  1955-05-08       Yuping     Dayang   F
# 300021   76671        s0001  1959-06-09       Ortrud   Plessier   M
# 300022  264920        s0001  1959-09-22        Percy   Samarati   F
# 300023  464503        s0002  1964-05-31       Arvind  Slobodova   M
#
#          hire_date title_id            title  salary
# 0       1990-04-28    s0001            Staff   40000
# ...

# %%
# create dataframe for average salary by title
df_average_salary = df_merge.groupby('title')['salary'].mean().reset_index()

# set index to column "title"
df_average_salary = df_average_salary.set_index('title')

# sort values in descending order
df_average_salary = df_average_salary.sort_values(by=["salary"], ascending=False)

# display dataframe
df_average_salary
# Out:
#                           salary
# title
# Senior Staff        58550.172704
# Staff               58465.382850
# Manager             51531.041667
# Technique Leader    48582.896092
# Assistant Engineer  48564.434447
# Engineer            48535.336511
# Senior Engineer     48506.799871

# %%
# create a bar chart of average salary by title

# determine fig and ax
fig1, ax1 = plt.subplots()

# determine type of plot and format
df_average_salary.plot(kind="bar",
                       figsize=(7,7),
                       ax=ax1,
                       color="limegreen",
                       edgecolor="black",
                       xlabel="Job Title",
                       ylabel="Average Salary ($)",
                       title="Average Salary by Job Title");

# rotate xticks
plt.xticks(rotation = 75)

# apply grid
ax1.yaxis.grid()

# display bar chart
fig1.tight_layout();

# save figure
plt.savefig("../sql-challenge/Images/Bonus - Bar Chart Average Salary.png")
